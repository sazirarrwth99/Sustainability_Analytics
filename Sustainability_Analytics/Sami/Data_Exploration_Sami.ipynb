# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.datasets import load_nfl
from yellowbrick.cluster import KElbowVisualizer
from itertools import permutations

# %%
# Read in the data
df_firm_data = pd.read_csv('../Daten/FDS/Firm_Data.csv', index_col=0)
df_id_data = pd.read_csv('../Daten/FDS/ID_Data.csv', index_col=0)
df_mc_data = pd.read_csv('../Daten/FDS/MC_Data.csv', index_col=0)
df_return_data = pd.read_csv('../Daten/FDS/Return_Data.csv', index_col=0)

# %%
def show_data(df_firm_data, df_id_data, df_mc_data, df_return_data):
    #show heads if true
    print("firm data")
    display(df_firm_data.head())
    print("id data")
    display(df_id_data.head())
    print("mc data")
    display(df_mc_data.head())
    print("return data")
    display(df_return_data.head())

# %%
#make the dataframes a little bit more readable
def make_readable(df_firm_data, df_id_data, df_mc_data, df_return_data):
    """- sets date as index where suitaeble"""
    df_firm_data.index = pd.to_datetime(df_firm_data["Date"])
    df_mc_data.index = pd.to_datetime(df_mc_data["Date"])
    df_return_data.index = pd.to_datetime(df_return_data["Date"])
    return df_firm_data, df_id_data, df_mc_data, df_return_data
    
df_firm_data, df_id_data, df_mc_data, df_return_data = make_readable(df_firm_data, df_id_data, df_mc_data, df_return_data)

# %%
show_data(df_firm_data, df_id_data, df_mc_data, df_return_data)
# Out:
# firm data
#                   Date  Total Current Assets  Total Current Liabilities  \
# Date
# 2009-12-31  31/12/2009            434.373405                 483.824655
# 2010-12-31  31/12/2010            579.778906                 580.095207
# 2011-12-31  31/12/2011            598.968478                 607.694345
# 2012-12-31  31/12/2012            615.523874                 601.137943
# 2013-12-31  31/12/2013            748.229068                 814.064189
#
#             Total Debt  Total Assets, Reported  Net Income - Actual  \
# Date
# 2009-12-31  718.957376             1361.504594           107.309409
# 2010-12-31  901.298414             1655.358922           139.656087
# 2011-12-31  893.154869             1660.096296           122.255528
# 2012-12-31  907.121844             1658.099764           100.765756
# 2013-12-31  895.874010             1714.940377           133.919162
#
#             Revenue Per Share  Total Revenue  Total Equity  \
# Date
# 2009-12-31           7.068281    1561.383359     -3.988004
# 2010-12-31           8.006665    1800.699024    -48.552134
# 2011-12-31           7.912984    2010.689188     35.059289
# 2012-12-31           7.914423    2030.840850     59.968319
# 2013-12-31           8.716901    2133.025672     65.996482
#
#             Total CO2 Equivalent Emissions To Revenues USD in million  \
# Date
# 2009-12-31                                                NaN
# 2010-12-31                                                NaN
# 2011-12-31                                                NaN
# 2012-12-31                                                NaN
# 2013-12-31                                          31.296503
#
#             ESG Score  Social Pillar Score  Governance Pillar Score  \
# Date
# 2009-12-31  51.267135            45.539754                59.077651
# 2010-12-31  50.550242            57.622888                31.890959
# 2006-04-30  25696.54916  1500.917885  1930.076236  8779.218311     0.0
#
#                  GEO.MI          NRG      MYTr.AT      TEMN.S
# Date
# 2005-12-31  2844.375572  3802.640450   875.088506  536.676851
# 2006-01-31  2939.943338  3895.446827  1242.051819  573.175661
# 2006-02-28  3168.139495  3490.326814  1237.343398  590.161549
# 2006-03-31  3450.354232  6194.021936  1142.026571  541.855421
# 2006-04-30  3698.005018  6518.653337  1185.646517  545.485527
#
# [5 rows x 1884 columns]
# return data
#                   Date     INTU.O         HL    GILG.DE        APH  SGH.O  \
# Date
# 2000-01-31  2000-01-31   0.625652 -12.000000  11.671470   1.971831    0.0
# 2000-02-29  2000-02-29 -12.953368   4.545455  -2.580645  17.771639    0.0
# 2000-03-31  2000-03-31   3.571429  -4.347826   3.973510  27.912432    0.0
# 2000-04-30  2000-04-30 -33.908046  -9.090909   5.732484  24.694377    0.0
# 2000-05-31  2000-05-31   0.869565 -15.000000  11.862429 -28.235294    0.0
#
#             PMAG.S        RTX  SOLARb.CO    OBEL.BR  ...  XYL   SCHN.PA  \
# Date                                                 ...
# 2000-01-31     0.0 -18.557692   0.000000 -25.558487  ...  0.0 -6.991661
# 2000-02-29     0.0  -3.408844  -2.777778  13.397921  ...  0.0 -7.586207
# 2000-03-31     0.0  24.049080   3.428571  -1.521150  ...  0.0 -0.447761
# 2000-04-30     0.0  -1.582591   2.287293 -14.621244  ...  0.0  7.946027
# 2000-05-31     0.0  -2.515897   2.040297  -9.491945  ...  0.0 -0.833333
#
#                PRGO.K      TRELb.ST  SRG.MI  LOG.MC  GEO.MI  NRG    MYTr.AT  \
# Date
# 2000-01-31   7.421875 -1.045752e+01     0.0     0.0     0.0  0.0 -23.040752
# 2000-02-29 -14.545455 -1.021898e+01     0.0     0.0     0.0  0.0 -18.533605
# 2000-03-31   3.404255 -8.130081e-01     0.0     0.0     0.0  0.0   1.125000
# 2000-04-30 -25.102881  3.516658e+00     0.0     0.0     0.0  0.0 -20.519159
# 2000-05-31   5.494505 -4.023120e-10     0.0     0.0     0.0  0.0  19.284603
#
#             TEMN.S
# Date
# 2000-01-31     0.0
# 2000-02-29     0.0
# 2000-03-31     0.0
# 2000-04-30     0.0
# 2000-05-31     0.0
#
# [5 rows x 1884 columns]

# %%
def make_df_visualize_without_clustering(df_firm_data, df_id_data, df_mc_data, df_return_data, visualize=True):
    """
    - makes a dataframe for visualization without clustering
    - if visualize is true, it will show the data
    - it visualizes calculates the return, risk, and esg score
    - the colorization can by set, by default it is set to the industry
    - the company name of a datapoint is shown when hovering over it
    """
    df_company = df_id_data.copy()
