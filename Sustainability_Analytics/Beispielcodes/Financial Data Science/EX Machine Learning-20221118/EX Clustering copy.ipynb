# %% [markdown]
# # Create Spotify Playlist with Machine Learning

# %% [markdown]
# We are given a data set of spotify songs with specific audio features. We want to create new playlists with songs that sound similar. For this, we use machine learning clustering algorithms.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.datasets import load_nfl
from yellowbrick.cluster import KElbowVisualizer
from itertools import permutations

# %%
df = pd.read_csv("audio_features.csv")

# %% [markdown]
# ## Tasks
# - Choose 3 audio features that you want to base the playlist creation on
# (i.e. 'energy', 'instrumentalness', 'loudness')
# - Scale the data
# - Use the k-means method to compute clusters and use the elbow method to determine a good amount of clusters
#
# If you see that the clustering does not work well (low amount of clusters, large dispersion, ...), consider choosing other audio features and test if it works better

# %%
# Choose features

# %%
# Scale (MinMax Scaling of the features)

# %%
# Use k-means + elbow method

# %% [markdown]
# ## Tasks
# - Using the optimal amount of clusters, compute the clusters for all songs
# - Plot the songs in a 3d space

# %%
# Compute clusters

# %%
import plotly.express as px
# 3D-plot

# %% [markdown]
# ![Bildschirm%C2%ADfoto%202022-11-15%20um%2008.23.27.png](attachment:Bildschirm%C2%ADfoto%202022-11-15%20um%2008.23.27.png)

# %% [markdown]
# ## Tasks
# - For every cluster, plot the distribution of the audio features in the respective cluster

# %%
# violinplot for every cluster

# %% [markdown]
# ## Advanced Task
# At the beginning, we arbitrarily chose the features that our clusters are based on. Instead, we might be interested in finding out which features work best to build playlists (clusters).
#
# We can use the Silhouette score for this reason. The Silhouette Coefficient is calculated using the mean intra-cluster distance (a) and the mean nearest-cluster distance (b) for each sample. The Silhouette Coefficient for a sample is (b - a) / max(a, b). To clarify, b is the distance between a sample and the nearest cluster that the sample is not a part of.
#
# The best value is 1 and the worst value is -1. Values near 0 indicate overlapping clusters. Negative values generally indicate that a sample has been assigned to the wrong cluster, as a different cluster is more similar.
#
# ### Compute the silhouette scores for all feature permutations and record the ones with the highest scores

# %%
# Compute the silhouette scores for all feature permutations and record the ones with the highest scores
# Out:
#                                           features     score elbow
# 0              [instrumentalness, liveness, tempo]  0.410717     4
# 1        [danceability, instrumentalness, valence]  0.431000     3
# 2             [acousticness, speechiness, valence]  0.451188     2
# 3             [energy, instrumentalness, liveness]  0.440182     4
# 4       [danceability, instrumentalness, liveness]  0.412562     4
# 5             [danceability, speechiness, valence]  0.403326     3
# 6               [acousticness, liveness, loudness]  0.552235     2
# 7   [acousticness, danceability, instrumentalness]  0.542093     2
# 8            [acousticness, liveness, speechiness]  0.514793     2
# 9               [acousticness, speechiness, tempo]  0.489719     2
# 10            [energy, instrumentalness, loudness]  0.513070     3
# 11      [danceability, instrumentalness, loudness]  0.680276     2
# 12         [energy, instrumentalness, speechiness]  0.493975     4
# 13           [acousticness, loudness, speechiness]  0.565742     2
# 14                   [liveness, loudness, valence]  0.407732     3
# 15                 [acousticness, energy, valence]  0.478720     2
# 16       [instrumentalness, loudness, speechiness]  0.731318     2
# 17       [acousticness, instrumentalness, valence]  0.492861     2
# 18      [acousticness, instrumentalness, liveness]  0.553179     2
# 19                   [acousticness, energy, tempo]  0.511228     2
# 20          [instrumentalness, liveness, loudness]  0.715147     2
# 21         [acousticness, instrumentalness, tempo]  0.522492     2
# 22       [instrumentalness, liveness, speechiness]  0.669346     2
# 23   [danceability, instrumentalness, speechiness]  0.431994     4
# 24                [liveness, speechiness, valence]  0.431635     4
# 25                [loudness, speechiness, valence]  0.439650     3
# 26           [acousticness, danceability, valence]  0.448942     2
# 27               [acousticness, loudness, valence]  0.492148     2
# 28          [acousticness, danceability, liveness]  0.487965     2
# 29                  [acousticness, tempo, valence]  0.428739     2
# 30                [acousticness, energy, liveness]  0.530996     2
# 31             [acousticness, danceability, tempo]  0.472312     2
# 32        [instrumentalness, speechiness, valence]  0.503809     4
# 33               [liveness, loudness, speechiness]  0.480361     2
# 34          [acousticness, danceability, loudness]  0.547618     2
# 35               [acousticness, liveness, valence]  0.441351     2
# 36                [acousticness, energy, loudness]  0.582059     2
# 37          [instrumentalness, speechiness, tempo]  0.434323     4
# 38                 [energy, loudness, speechiness]  0.477509     3
# 39                [danceability, energy, loudness]  0.403493     2
# 40             [acousticness, energy, speechiness]  0.543208     2
# 41      [acousticness, instrumentalness, loudness]  0.615554     2
# 42   [acousticness, instrumentalness, speechiness]  0.571411     2
# 43                 [acousticness, liveness, tempo]  0.474602     2
# 44             [energy, instrumentalness, valence]  0.411828     3
# 45                    [energy, liveness, loudness]  0.407603     2
# 46                 [energy, liveness, speechiness]  0.412882     4
# 47           [instrumentalness, loudness, valence]  0.485115     3
# 48        [acousticness, energy, instrumentalness]  0.576278     2
# 49                 [acousticness, loudness, tempo]  0.526934     2
# 50        [danceability, energy, instrumentalness]  0.401754     3
# 51            [acousticness, danceability, energy]  0.527830     2
# 52             [instrumentalness, loudness, tempo]  0.674063     2
# 53       [acousticness, danceability, speechiness]  0.503670     2
# 54           [instrumentalness, liveness, valence]  0.465398     4
