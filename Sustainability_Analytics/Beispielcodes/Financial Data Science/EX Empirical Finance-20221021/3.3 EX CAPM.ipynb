# %%
import pandas_datareader.data as web
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
# read data
data = pd.read_csv("Returns.csv")

# set Date as index
data.set_index("Date",inplace=True)

# inspect your data
data.head()

# %%
# extract risk free rate and save in own dataframe

# %%
# extract market return (dow jones index) and save in own dataframe

# %%
# drop columns, so that the data dataframe contains only single stock returns

# %% [markdown]
# # CAPM Betas
# The CAPM Beta is calculated by a time series regression of the market's excess returns on an asset's excess returns.
# - Calculate the annual expected returns of all assets
# - Calculate the CAPM Betas of all assets
# - Plot the Betas vs exp. annual return

# %%
# Calculate annualised mean returns of all assets in data
# hint: better use a new dataframe

# %%
# Calculate the CAPM Betas of all assets
# hint: create a new dataframe to save the regression parameters for every stock, you will need it later
# you can see an example of this below at the end of this excercise

# %%
# Plot the Betas vs. the expected annual return
# hint: use scatter plot from matplotlib and change the marker symbol
# Out:
# Text(0, 0.5, 'Exp. Annual Return (in %)')

# %% [markdown]
# # Security Market Line
# - Compute the security market line equation
# - Plot the SML and the securities
# - Predict the expected return for all stocks
# - Determine if stocks are under-/overvalued

# %%
# set yearly risk free rate for later use
risk_free = 2.07

# calculate the annual expected market return

# %%
# Calculate the Security Market Line (SML)
# Following steps are just suggestions, own solutions are also welcome


# 1. define an own function for the SML


# 2. define the beta range (x-values of the SML function)
# hint: there is a numpy function, which automatically fills an array in evenly spaced steps for a given interval


# 3. calculate SML values for each step in you beta range
# save your SML values in a new dataframe

# %%
# 1. plot the SML
# 2. research how to add the single stock betas to the plot

# %%
# determine if stocks are under- or overvalued
# hint: you can add a new column to the (previously) created dataframe
# Out:
#          Alpha      Beta  Exp_Return  Pred_Return  Undervalued
# UNH   1.475841  0.661229   28.654211     8.690960            1
# GS   -0.584118  1.525217   10.693749    17.342166            0
# HD    1.142432  1.032343   28.733059    12.406962            1
# MSFT  0.863320  1.064355   25.003448    12.727501            1
# AMGN  0.759863  0.806388   20.104618    10.144450            1
# MCD   0.868983  0.484883   17.515449     6.925190            1
# CAT  -0.087369  1.621681   18.646324    18.308071            1
# V     1.304166  0.850761   28.673312    10.588759            1
# HON   0.492584  1.234941   21.873061    14.435600            1
# AXP   0.272290  1.123947   17.326679    13.324203            1
# JNJ   0.379856  0.695831   13.453855     9.037425            1
# BA    0.612162  1.321613   24.761850    15.303454            1
# CRM   1.471784  0.915378   32.141229    11.235775            1
# TRV   0.228728  0.999380   15.160919    12.076896            1
# ...
